# %%
from myfunctions import *

# %%
fdf, img = fullInference()

# %%
fdf
# Out:
#       xc   yc  width  height  line     char  confidence
# 0    165   37     45      43     0  Epsilon    1.000000
# 1    208   34     50      45     0      Tau    1.000000
# 2    258   34     48      42     0    Alpha    1.000000
# 3    302   36     44      47     0      Tau    1.000000
# 4    342   35     43      55     0    Theta    1.000000
# ..   ...  ...    ...     ...   ...      ...         ...
# 99   578  498     56      61     7  Epsilon    1.000000
# 100  628  497     56      59     7    Kappa    1.000000
# 101  670  498     36      55     7       Mu    1.000000
# 102  295  583     68      45     8       Mu    0.851873
# 103  373  578     79      52     8       Mu    1.000000
#
# [104 rows x 7 columns]
